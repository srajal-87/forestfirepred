# %% [markdown]
# ## Algerian Forest Fires Dataset

# %% [markdown]
# ### Data Set Information:
#
# The dataset includes 244 instances that regroup a data of two regions of Algeria,namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# 122 instances for each region.
#
# The period from June 2012 to September 2012. The dataset includes 11 attribues and 1 output attribue (class) The 244 instances have been classified into fire(138 classes) and not fire (106 classes) classes.
#
# ### Attribute Information:
# #### 1 Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012) Weather data observations
# #### 2 Temp : temperature noon (temperature max) in Celsius degrees: 22 to 42
# #### 3 RH : Relative Humidity in %: 21 to 90
# #### 4 Ws :Wind speed in km/h: 6 to 29
# #### 5 Rain: total day in mm: 0 to 16.8 FWI Components
# #### 6 Fine Fuel Moisture Code (FFMC) index from the FWI system: 28.6 to 92.5
# #### 7 Duff Moisture Code (DMC) index from the FWI system: 1.1 to 65.9
# #### 8 Drought Code (DC) index from the FWI system: 7 to 220.4
# #### 9 Initial Spread Index (ISI) index from the FWI system: 0 to 18.5
# #### 10 Buildup Index (BUI) index from the FWI system: 1.1 to 68
# #### 11 Fire Weather Index (FWI) Index: 0 to 31.1
# #### 12 Classes: two classes, namely Fire and not Fire

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
## read the dataset
df=pd.read_csv("Algerian_forest_fires_dataset.csv")

# %% [markdown]
# ### first we clean our data(EDA: Exploratory data analysis)

# %%
df.iloc[122:136,:]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 122                            NaN    NaN   NaN          NaN  NaN  NaN    NaN
# 123  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 124                            day  month  year  Temperature   RH   Ws  Rain
# 125                              1      6  2012           32   71   12    0.7
# 126                              2      6  2012           30   73   13      4
# 127                              3      6  2012           29   80   14      2
# 128                              4      6  2012           30   64   14      0
# 129                              5      6  2012           32   60   14    0.2
# 130                              6      6  2012           35   54   11    0.1
# 131                              7      6  2012           35   44   17    0.2
# 132                              8      6  2012           28   51   17    1.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %% [markdown]
# ## DATA CLEANING

# %%
# if any value missing in any column of that row then return that row
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
#df['label']=0
#df.iloc[123:,-1]=1

# %%
df.loc[:122,'Region']=0
df.loc[123:,'Region']=1

# %%
#convert the dytpe of region from float to int with the help of astype
df['Region']=df['Region'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       247 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 28.1+ KB

# %%
df.isnull().sum()
# Out:
# day            1
# month          2
# year           2
# Temperature    2
#  RH            2
#  Ws            2
# Rain           2
# FFMC           2
# DMC            2
# DC             2
# ISI            2
# BUI            2
# FWI            2
# Classes        3
# Region         0
# dtype: int64

# %%
# drop rows whose any value is null

df=df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
# remove 122nd row
df=df.drop(labels=122,axis=0).reset_index(drop=True)

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
# remove the space in the column names
# strip: remove leading and trailing characters
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(1), object(14)
# memory usage: 27.7+ KB

# %% [markdown]
# ## change the datatype of the colums in to INT from month to ws

# %%
df[['day','month','year','Temperature','RH','Ws']] = df[['day','month','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: int32(7), object(8)
# memory usage: 22.0+ KB

# %% [markdown]
# ## change the remaining columns into float datatype

# %%
features=[feature for feature in df.columns if df[feature].dtypes!=int]

# %%
for feature in features:
    if feature=='Classes':
        continue
    df[feature]=df[feature].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int32
#  1   month        243 non-null    int32
#  2   year         243 non-null    int32
#  3   Temperature  243 non-null    int32
#  4   RH           243 non-null    int32
#  5   Ws           243 non-null    int32
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int32
# dtypes: float64(7), int32(7), object(1)
# memory usage: 22.0+ KB

# %% [markdown]
# ## save our cleaned data to another csv file

# %%
df.to_csv("Algerian_forest_fires_cleaned_dataset.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df_copy=df

# %% [markdown]
# ### Feature Engineering
# #### drop the columns which are not important

# %%
df_copy=df_copy.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI      Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# convet the classes categorical feature in to numeric
n=df_copy.shape[0]
print(n)
# Out:
# 243

# %%
df_copy['Classes']=df_copy['Classes'].str.strip()

# %%
mapping={'not fire':0,'fire':1}

# %%
df_copy['Classes']=df_copy['Classes'].apply(lambda x:mapping[x])

# %%
# Encoding the categories of the classes using numpy
#we use str.conatins because there is a space in categoriacl values so my result is inefficient

# df_copy['Classes']=np.where(df_copy['Classes'].str.contains('not_fire'),0,1)

# %% [markdown]
# #### value_counts() is used to count unique values in a Series.

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
## acess the row whose classes value =1(fire)
df_copy[df_copy['Classes']==1]
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI   FWI  Classes  \
# 5             31  67  14   0.0  82.6   5.8   22.2   3.1   7.0   2.5        1
# 6             33  54  13   0.0  88.2   9.9   30.5   6.4  10.9   7.2        1
# 7             30  73  15   0.0  86.6  12.1   38.3   5.6  13.5   7.1        1
# 10            31  65  14   0.0  84.5  12.5   54.3   4.0  15.8   5.6        1
# 11            26  81  19   0.0  84.0  13.8   61.4   4.8  17.7   7.1        1
# ..           ...  ..  ..   ...   ...   ...    ...   ...   ...   ...      ...
# 231           29  41   8   0.1  83.9  24.9   86.0   2.7  28.9   5.6        1
# 233           35  34  17   0.0  92.2  23.6   97.3  13.8  29.4  21.6        1
# 234           33  64  13   0.0  88.9  26.1  106.3   7.1  32.4  13.7        1
# 235           35  56  14   0.0  89.0  29.4  115.6   7.5  36.0  15.2        1
# 238           30  65  14   0.0  85.4  16.0   44.5   4.5  16.9   6.5        1
#
#      Region
# 5         0
# 6         0
# ...

# %%
# define the correlation between the columns
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
# bins:Bins in a histogram represent intervals into which the data range is divided. Each bin contains the count of data points that fall within that interval.
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_11440\1062445420.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
## normalize gives me percenate of each feature in class column
percentage=df_copy['Classes'].value_counts(normalize=True)*100
categories=['Fire','Not Fire']

# %% [markdown]
# #### pie chart bewteen the percenatge of categorical values

# %%
# autopct='%1.1f%%': This formats the labels inside the pie chart to display the percentage values with one decimal place.
plt.figure(figsize=(7,12))
plt.pie(percentage,labels=categories,autopct="%1.1f%%",explode=(0.2,0))
plt.title('Pie chart')
# Out:
# Text(0.5, 1.0, 'Pie chart')

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
# create a heatmap
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
plt.boxplot(df['FWI'],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c575ffd990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c5760405d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c57603eb10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c576041b10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c57603d290>],
#  'means': []}

# %%
df['Classes']=df['Classes'].str.strip()

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire        137
# not fire    106
# Name: count, dtype: int64

# %% [markdown]
# ## monthly fire analysis

# %%
# Monthly fire analysis
df_temp1=df[df['Region']==1]
plt.subplots(figsize=(13,7))
sns.set_style('whitegrid')
sns.countplot(data=df_temp1,x='month',hue='Classes')
plt.title('monthly fire plot of Sidi Bel-abbes region located in the northwest of Algeria. ')
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
df_temp2=df[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('dark')
sns.countplot(data=df_temp2,x='month',hue='Classes')
plt.title('monthly fire plot of Bejaia region located in the northwest of Algeria. ')
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...
